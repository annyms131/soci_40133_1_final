# %%
# from Bio import Entrez, Medline
# import pandas as pd

# %%
# my_key = ""
# my_email = ""

# Entrez.api_key = my_key
# Entrez.email = my_email

# query_raw = 'social[All Fields] AND determinants[All Fields]'
# handle_1 = Entrez.esearch(db="pubmed", term=query_raw, retmax = 1000000)
# record_1 = Entrez.read(handle_1)
# pmid_lst_1 = record_1['IdList']

# %%
# with open('pmid_raw.txt', 'w') as file:
#     for pmid in pmid_lst_1:
#         file.write(pmid + "\n")

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[0:2000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# a = pd.DataFrame(medline)
# a.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_a.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[2000:4000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# b = pd.DataFrame(medline)
# b.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_b.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[4000:6000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# c = pd.DataFrame(medline)
# c.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_c.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[6000:8000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# d = pd.DataFrame(medline)
# d.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_d.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[8000:10000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# e = pd.DataFrame(medline)
# e.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_e.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[10000:12000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# f = pd.DataFrame(medline)
# f.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_f.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[12000:14000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# g = pd.DataFrame(medline)
# g.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_g.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[14001:16000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# h = pd.DataFrame(medline)
# h.to_csv(r'C:\Users\Yoojin\Desktop\soci_40133_final\data\df_h.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[16000:18000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# i = pd.DataFrame(medline)
# i.to_csv(r'C:\Users\Yoojin\Desktop\Content-Analysis-2020\final\df_i.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[18000:20000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# j = pd.DataFrame(medline)
# j.to_csv(r'C:\Users\Yoojin\Desktop\Content-Analysis-2020\final\df_j.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[20000:22000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# k = pd.DataFrame(medline)
# k.to_csv(r'C:\Users\Yoojin\Desktop\Content-Analysis-2020\final\df_k.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[22000:24000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# l = pd.DataFrame(medline)
# l.to_csv(r'C:\Users\Yoojin\Desktop\Content-Analysis-2020\final\df_l.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[24000:26000], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# m = pd.DataFrame(medline)
# m.to_csv(r'C:\Users\Yoojin\Desktop\Content-Analysis-2020\final\df_m.csv', index = False, header=True)

# %%
# handle = Entrez.efetch(db="pubmed", id=pmid_lst_1[26000:27522], rettype = 'medline')
# medline = [i for i in Medline.parse(handle)]
# n = pd.DataFrame(medline)
# n.to_csv(r'C:\Users\Yoojin\Desktop\Content-Analysis-2020\final\df_n.csv', index = False, header=True)

# %%
# df_final = pd.concat([a, b, c, d, e, f, g, h, i, j, k, l, m, n], axis=0)

# %%
# df_final

# %%
# df = df_final[['PMID','TI', 'AB', 'DP', 'JT', 'PL']]
# df.isnull().sum()
# df = df.dropna()
# df.head(5)
