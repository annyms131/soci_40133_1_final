# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
#Make sure you update it before starting this notebook
import lucem_illud_2020 #pip install -U git+git://github.com/Computational-Content-Analysis-2020/lucem_illud_2020.git


import sklearn
import sklearn.feature_extraction.text

#import scipy.cluster.hierarchy
import gensim#For topic modeling
import requests #For downloading our datasets
import numpy as np #for arrays
import pandas #gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import matplotlib.cm #Still for graphics

#This 'magic' command makes the plots work better
#in the notebook, don't use it outside of a notebook.
#Also you can ignore the warning, it
# %matplotlib inline

# %%
df = pandas.read_csv('t\df_90.csv', index_col=0)

# %%
#Apply our functions
df['tokenized_text'] = df['AB'].apply(lambda x: lucem_illud_2020.word_tokenize(x))
df['normalized_tokens'] = df['tokenized_text'].apply(lambda x: lucem_illud_2020.normalizeTokens(x))

# %% [markdown]
# ### Exercise 1
#
# Construct cells immediately below this that construct features and cluster your documents using K-means and a variety of cluster numbers. Interrogate the cluster contents in terms of both documents and features. Identify the "optimal" cluster number with Silhouette analysis. Plot clusters and features after reducing with PCA. What does this cluster structure reveal about the organization of documents in your corpora?

# %%
ngTFVectorizer = sklearn.feature_extraction.text.TfidfVectorizer(max_df=0.5, 
                                                                 max_features=1000, min_df=3, 
                                                                 stop_words='english', 
                                                                 norm='l2')
groupsTFVects = ngTFVectorizer.fit_transform(df['AB'])

# %%
def dropMissing(wordLst, vocab):
    return [w for w in wordLst if w in vocab]

df['reduced_tokens'] = df['normalized_tokens'].apply(lambda x: dropMissing(x, ngTFVectorizer.vocabulary_.keys()))

# %%
dictionary = gensim.corpora.Dictionary(df['reduced_tokens'])

# %%
## create a list of tuples containing each token and its count 
## use the first half and save the remainder for testing 
corpus = [dictionary.doc2bow(text) for text in df['reduced_tokens']]

# %%
# serialize the corpus as a file and load it 
gensim.corpora.MmCorpus.serialize('abstract.mm', corpus)
abmm = gensim.corpora.MmCorpus('abstract.mm')

# %%
# correctly formatted corpus that can be used for topic modeling and induction 
senlda = gensim.models.ldamodel.LdaModel(corpus=abmm, id2word=dictionary, num_topics=20, alpha='auto', eta='auto')

# %%
# sen1Bow = dictionary.doc2bow(df['reduced_tokens'][0])
# sen1lda = senlda[sen1Bow]
# print("The topics of the text: {}".format(df['TI'][0]))
# print("are: {}".format(sen1lda))

# %%
ldaDF = pandas.DataFrame({
        'titles' : df['TI'],
        'topics' : [senlda[dictionary.doc2bow(l)] for l in df['reduced_tokens']]
    })

# %%
topicsProbDict = {i : [0] * len(ldaDF) for i in range(senlda.num_topics)}

for index, topicTuples in enumerate(ldaDF['topics']):
    for topicNum, prob in topicTuples:
        topicsProbDict[topicNum][index] = prob

for topicNum in range(senlda.num_topics):
    ldaDF['topic_{}'.format(topicNum)] = topicsProbDict[topicNum]

# %%
K = senlda.num_topics  # N documents, K topics
topic_labels = ['Topic #{}'.format(k) for k in range(K)]

topicsDict = {}
for topicNum in range(senlda.num_topics):
    topicWords = [w for w, p in senlda.show_topic(topicNum)]
    topicsDict['Topic_{}'.format(topicNum)] = topicWords

wordRanksDF = pandas.DataFrame(topicsDict)
wordRanksDF
# Out:
#        Topic_0      Topic_1      Topic_2      Topic_3      Topic_4  \
# 0        study       health        study  determinant      patient
# 1       health  determinant          use          age       factor
# 2  determinant  development  determinant      support      disease
# 3         rate        study       result       stress        study
# 4      support    influence       family        study  determinant
# 5    mortality          age      support       health      smoking
# 6         high     analysis       health     analysis          age
# 7         risk       result      alcohol        model        child
# 8          use        group        group          job         risk
# 9        level    mortality     physical       result         high
#
#        Topic_5      Topic_6      Topic_7      Topic_8      Topic_9 Topic_10  \
# 0       health       health       health       health          age      use
# 1       status      disease     behavior        child        study   condom
# 2        model  determinant  determinant        study         year    study
# 3       female       factor        group       status         care    child
# 4  determinant    influence          use  determinant       health  patient
# 5    education        birth        study     physical       factor     high
# 6   population         high          age      patient        child      sex
# 7     research        study         risk       result          use   effect
# 8        study   population       sexual          age  determinant  disease
# 9       result        child       factor      service     variable      age
#
#       Topic_11     Topic_12     Topic_13     Topic_14     Topic_15  \
# 0       family       health      patient       health       health
# 1        level         care        study       factor        study
# 2        study       factor       health    mortality       effect
# 3       health        study          age        study          use
# 4  determinant      patient         risk  determinant  determinant
# 5      support         self  determinant       family       factor
# 6        death        child         high       gender      control
# 7        group  determinant       factor       policy    treatment
# 8    influence        group       report          use        level
# 9         life     behavior       family       effect       change
#
#       Topic_16     Topic_17     Topic_18     Topic_19
# 0       factor        child     attitude      patient
# 1          use         work          age     activity
# 2        study       health       factor        study
# 3       health          age     increase        child
# 4  determinant        study        urban       health
# 5    treatment         year       health  determinant
# 6         high       result        study          use
# 7      support         risk         rate       condom
# 8         self  determinant   population       result
# 9         drug    cognitive  determinant       factor
